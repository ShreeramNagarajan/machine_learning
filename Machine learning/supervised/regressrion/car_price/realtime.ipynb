# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model  import LinearRegression
import numpy as np
import seaborn as sns
sns.set()

# %%
raw_data=pd.read_csv("1.04. Real-life example.csv")
raw_data
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4343         Toyota   14200.0      sedan       31      NaN      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year              Model
# 0             yes  1991                320
# ...

# %%
raw_data.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4345    4173.000000   4345  4345.000000  4195.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           936            NaN   1649          NaN          NaN
# mean           NaN   19418.746935    NaN   161.237284     2.790734
# std            NaN   25584.242620    NaN   105.705797     5.066437
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    86.000000     1.800000
# 50%            NaN   11500.000000    NaN   155.000000     2.200000
# 75%            NaN   21700.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year    Model
# count         4345         4345  4345.000000     4345
# ...

# %%
data=raw_data.drop(["Model"],axis=1)
data
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4343         Toyota   14200.0      sedan       31      NaN      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year
# 0             yes  1991
# 1             yes  1999
# 2             yes  2003
# ...

# %%
data.describe(include="all")
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4345    4173.000000   4345  4345.000000  4195.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           936            NaN   1649          NaN          NaN
# mean           NaN   19418.746935    NaN   161.237284     2.790734
# std            NaN   25584.242620    NaN   105.705797     5.066437
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    86.000000     1.800000
# 50%            NaN   11500.000000    NaN   155.000000     2.200000
# 75%            NaN   21700.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         4345         4345  4345.000000
# unique           4            2          NaN
# ...

# %%
new_data=data.dropna(axis=0)
new_data.describe(include="all")
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4025    4025.000000   4025  4025.000000  4025.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           880            NaN   1534          NaN          NaN
# mean           NaN   19552.308065    NaN   163.572174     2.764586
# std            NaN   25815.734988    NaN   103.394703     4.935941
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    90.000000     1.800000
# 50%            NaN   11500.000000    NaN   158.000000     2.200000
# 75%            NaN   21900.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         4025         4025  4025.000000
# unique           4            2          NaN
# ...

# %%
sns.displot(new_data["Price"])

# %%
q=new_data["Price"].quantile(0.99)
q
# Out:
# 129812.51999999981

# %%
data1=new_data[new_data["Price"]<q]
data1.describe()
# Out:
#                Price      Mileage      EngineV         Year
# count    3984.000000  3984.000000  3984.000000  3984.000000
# mean    17837.117460   165.116466     2.743770  2006.292922
# std     18976.268315   102.766126     4.956057     6.672745
# min       600.000000     0.000000     0.600000  1969.000000
# 25%      6980.000000    93.000000     1.800000  2002.750000
# 50%     11400.000000   160.000000     2.200000  2007.000000
# 75%     21000.000000   230.000000     3.000000  2011.000000
# max    129222.000000   980.000000    99.990000  2016.000000

# %%
m=new_data["Mileage"].quantile(0.99)
m
# Out:
# 434.5199999999995

# %%
sns.displot(data1["Price"])

# %%
data2=data1[data1["Mileage"]<m]
data2.describe()
# Out:
#                Price      Mileage      EngineV         Year
# count    3943.000000  3943.000000  3943.000000  3943.000000
# mean    17936.780614   161.414659     2.747497  2006.393102
# std     19009.750360    95.940408     4.981033     6.593870
# min       600.000000     0.000000     0.600000  1969.000000
# 25%      7000.000000    92.000000     1.800000  2003.000000
# 50%     11500.000000   158.000000     2.200000  2007.000000
# 75%     21417.500000   230.000000     3.000000  2011.000000
# max    129222.000000   433.000000    99.990000  2016.000000

# %%
sns.displot(data2["Mileage"])

# %%
e=data2["EngineV"].quantile(0.99)
e
# Out:
# 6.0

# %%
data3=data2[data2["EngineV"]<e]
data3.describe(include="all")
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         3893    3893.000000   3893  3893.000000  3893.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           862            NaN   1482          NaN          NaN
# mean           NaN   17826.714606    NaN   161.527871     2.417480
# std            NaN   18920.569948    NaN    96.088932     0.896998
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    7000.000000    NaN    92.000000     1.800000
# 50%            NaN   11500.000000    NaN   158.000000     2.200000
# 75%            NaN   21000.000000    NaN   230.000000     3.000000
# max            NaN  129222.000000    NaN   433.000000     5.700000
#
#        Engine Type Registration         Year
# count         3893         3893  3893.000000
# unique           4            2          NaN
# ...

# %%
sns.displot(data["EngineV"])

# %%
sns.displot(data3["Year"])

# %%
y=data3["Year"].quantile(0.01)
y
# Out:
# 1987.0

# %%
data4=data3[data3["Year"]>y]
data4.describe()
# Out:
#                Price      Mileage      EngineV         Year
# count    3839.000000  3839.000000  3839.000000  3839.000000
# mean    18031.977106   160.788747     2.424108  2006.706173
# std     18965.444460    95.653088     0.899854     6.114986
# min       800.000000     0.000000     0.600000  1988.000000
# 25%      7200.000000    92.000000     1.800000  2003.000000
# 50%     11550.000000   157.000000     2.200000  2008.000000
# 75%     21500.000000   226.000000     3.000000  2012.000000
# max    129222.000000   433.000000     5.700000  2016.000000

# %%
sns.displot(data4["Year"])

# %%
data4=data4.reset_index(drop=True)
data4
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 3834     Volkswagen   11500.0        van      163      2.5      Diesel
# 3835         Toyota   17900.0      sedan       35      1.6      Petrol
# 3836  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 3837            BMW    6500.0      sedan        1      3.5      Petrol
# 3838     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year
# 0             yes  1991
# 1             yes  1999
# 2             yes  2003
# ...

# %%
data4.describe(include="all")
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         3839    3839.000000   3839  3839.000000  3839.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           848            NaN   1450          NaN          NaN
# mean           NaN   18031.977106    NaN   160.788747     2.424108
# std            NaN   18965.444460    NaN    95.653088     0.899854
# min            NaN     800.000000    NaN     0.000000     0.600000
# 25%            NaN    7200.000000    NaN    92.000000     1.800000
# 50%            NaN   11550.000000    NaN   157.000000     2.200000
# 75%            NaN   21500.000000    NaN   226.000000     3.000000
# max            NaN  129222.000000    NaN   433.000000     5.700000
#
#        Engine Type Registration         Year
# count         3839         3839  3839.000000
# unique           4            2          NaN
# ...

# %%
f,(ax1,ax2,ax3)=plt.subplots(1,3,sharey=True,figsize=(15,3))
ax1.scatter(data4["Mileage"],data4["Price"])
ax1.set_title("price and mileage")
ax2.scatter(data4["Year"],data4["Price"])
ax2.set_title("price and year")
ax3.scatter(data4["EngineV"],data4["Price"])
ax3.set_title("price and year")
plt.show()

# %%
Log_price=np.log(data4["Price"])
Log_price
# Out:
# 0        8.342840
# 1        8.974618
# 2        9.495519
# 3       10.043249
# 4        9.814656
#           ...
# 3834     9.350102
# 3835     9.792556
# 3836    11.736069
# 3837     8.779557
# 3838     9.510445
# Name: Price, Length: 3839, dtype: float64

# %%
data4["Log_price"]=Log_price

# %%
f,(ax1,ax2,ax3)=plt.subplots(1,3,sharey=True,figsize=(15,3))
ax1.scatter(data4["Mileage"],data4["Log_price"])
ax1.set_title("price and mileage")
ax2.scatter(data4["Year"],data4["Log_price"])
ax2.set_title("price and year")
ax3.scatter(data4["EngineV"],data4["Log_price"])
ax3.set_title("price and year")
plt.show()

# %%
data4
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 3834     Volkswagen   11500.0        van      163      2.5      Diesel
# 3835         Toyota   17900.0      sedan       35      1.6      Petrol
# 3836  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 3837            BMW    6500.0      sedan        1      3.5      Petrol
# 3838     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year  Log_price
# 0             yes  1991   8.342840
# 1             yes  1999   8.974618
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables=data4[["Mileage","Year","EngineV"]]
vif=pd.DataFrame()
vif["VIF"]=[variance_inflation_factor(variables,i) for i in range(variables.shape[1])]
vif["Features"]=variables.columns

# %%
vif
# Out:
#          VIF Features
# 0   3.800925  Mileage
# 1  10.829426     Year
# 2   8.260253  EngineV

# %%
no_milcolinear_data=data4.drop(["Year"],axis=1)
no_milcolinear_data
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 3834     Volkswagen   11500.0        van      163      2.5      Diesel
# 3835         Toyota   17900.0      sedan       35      1.6      Petrol
# 3836  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 3837            BMW    6500.0      sedan        1      3.5      Petrol
# 3838     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Log_price
# 0             yes   8.342840
# 1             yes   8.974618
# ...

# %%
no_milcolinear_data.describe(include="all")
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         3839    3839.000000   3839  3839.000000  3839.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           848            NaN   1450          NaN          NaN
# mean           NaN   18031.977106    NaN   160.788747     2.424108
# std            NaN   18965.444460    NaN    95.653088     0.899854
# min            NaN     800.000000    NaN     0.000000     0.600000
# 25%            NaN    7200.000000    NaN    92.000000     1.800000
# 50%            NaN   11550.000000    NaN   157.000000     2.200000
# 75%            NaN   21500.000000    NaN   226.000000     3.000000
# max            NaN  129222.000000    NaN   433.000000     5.700000
#
#        Engine Type Registration    Log_price
# count         3839         3839  3839.000000
# unique           4            2          NaN
# ...

# %%
data_with_dummy=pd.get_dummies(no_milcolinear_data,drop_first=True)
data_with_dummy
# Out:
#          Price  Mileage  EngineV  Log_price  Brand_BMW  Brand_Mercedes-Benz  \
# 0       4200.0      277      2.0   8.342840       True                False
# 1       7900.0      427      2.9   8.974618      False                 True
# 2      13300.0      358      5.0   9.495519      False                 True
# 3      23000.0      240      4.2  10.043249      False                False
# 4      18300.0      120      2.0   9.814656      False                False
# ...        ...      ...      ...        ...        ...                  ...
# 3834   11500.0      163      2.5   9.350102      False                False
# 3835   17900.0       35      1.6   9.792556      False                False
# 3836  125000.0        9      3.0  11.736069      False                 True
# 3837    6500.0        1      3.5   8.779557       True                False
# 3838   13500.0      124      2.0   9.510445      False                False
#
# ...

# %%
data_with_dummy.columns.values
# Out:
# array(['Price', 'Mileage', 'EngineV', 'Log_price', 'Brand_BMW',
#        'Brand_Mercedes-Benz', 'Brand_Mitsubishi', 'Brand_Renault',
#        'Brand_Toyota', 'Brand_Volkswagen', 'Body_hatch', 'Body_other',
#        'Body_sedan', 'Body_vagon', 'Body_van', 'Engine Type_Gas',
#        'Engine Type_Other', 'Engine Type_Petrol', 'Registration_yes'],
#       dtype=object)

# %%
cols=['Log_price', 'Mileage', 'EngineV', 'Brand_BMW',
       'Brand_Mercedes-Benz', 'Brand_Mitsubishi', 'Brand_Renault',
       'Brand_Toyota', 'Brand_Volkswagen', 'Body_hatch', 'Body_other',
       'Body_sedan', 'Body_vagon', 'Body_van', 'Engine Type_Gas',
       'Engine Type_Other', 'Engine Type_Petrol', 'Registration_yes']

# %%
data_preprocessed=data_with_dummy[cols]
data_preprocessed=data_preprocessed.astype(float)
data_preprocessed.describe()
# Out:
#          Log_price      Mileage      EngineV    Brand_BMW  \
# count  3839.000000  3839.000000  3839.000000  3839.000000
# mean      9.408485   160.788747     2.424108     0.162021
# std       0.873670    95.653088     0.899854     0.368518
# min       6.684612     0.000000     0.600000     0.000000
# 25%       8.881836    92.000000     1.800000     0.000000
# 50%       9.354441   157.000000     2.200000     0.000000
# 75%       9.975808   226.000000     3.000000     0.000000
# max      11.769287   433.000000     5.700000     1.000000
#
#        Brand_Mercedes-Benz  Brand_Mitsubishi  Brand_Renault  Brand_Toyota  \
# count          3839.000000       3839.000000    3839.000000   3839.000000
# mean              0.191196          0.078666       0.112529      0.129721
# std               0.393294          0.269252       0.316058      0.336040
# min               0.000000          0.000000       0.000000      0.000000
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variable=data_preprocessed[['Mileage', 'EngineV', 'Brand_BMW',
       'Brand_Mercedes-Benz', 'Brand_Mitsubishi', 'Brand_Renault',
       'Brand_Toyota', 'Brand_Volkswagen', 'Body_hatch', 'Body_other',
       'Body_sedan', 'Body_vagon', 'Body_van', 'Engine Type_Gas',
       'Engine Type_Other', 'Engine Type_Petrol', 'Registration_yes']]
vif2=pd.DataFrame()
vif2["VIF"]=[variance_inflation_factor(variable,i) for i in range(variable.shape[1])]
vif2["Features"]=variable.columns

# %%
vif2
# Out:
#          VIF             Features
# 0   4.547815              Mileage
# 1   8.314084              EngineV
# 2   2.341093            Brand_BMW
# 3   2.839523  Brand_Mercedes-Benz
# 4   1.653375     Brand_Mitsubishi
# 5   2.095628        Brand_Renault
# 6   2.204947         Brand_Toyota
# 7   2.872956     Brand_Volkswagen
# 8   1.469904           Body_hatch
# 9   1.528335           Body_other
# 10  3.117621           Body_sedan
# 11  1.586003           Body_vagon
# 12  2.484212             Body_van
# 13  1.690553      Engine Type_Gas
# 14  1.080819    Engine Type_Other
# 15  2.465851   Engine Type_Petrol
# 16  9.718673     Registration_yes

# %%
target=data_preprocessed["Log_price"]
Features=data_preprocessed.drop(["Log_price"],axis=1)

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
scaler.fit(Features)
# Out:
# StandardScaler()

# %%
scaled_data=scaler.transform(Features)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(scaled_data,target,test_size=0.2,random_state=365)
y_train
# Out:
# 1311    9.58
# 2928    8.41
# 3281    8.56
# 1751   10.30
# 2891    9.50
#         ...
# 428     9.98
# 859     9.79
# 801     8.82
# 2740    9.74
# 3666    9.35
# Name: Log_price, Length: 3071, dtype: float64

# %%
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_hat=reg.predict(x_train)

# %%
plt.scatter(y_train,y_hat)
plt.xlabel("targers(y_train)")
plt.ylabel("Predicted(y_hat)")
plt.xlim(6,13)
plt.ylim(6,13)
# Out:
# (6.0, 13.0)

# %%
##RESIDUALS PLOTe

# %%
sns.distplot(y_train-y_hat)
# Out:
# C:\Users\nrshr\AppData\Local\Temp\ipykernel_22948\984881160.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_train-y_hat)
# <Axes: xlabel='Log_price', ylabel='Density'>

# %%
reg.score(x_train,y_train)
# Out:
# 0.7537028424840986

# %%
reg_summary=pd.DataFrame(Features.columns.values,columns=["features"])
reg_summary["Wieghts"]=reg.coef_
reg_summary
# Out:
#                features   Wieghts
# 0               Mileage -0.469357
# 1               EngineV  0.209364
# 2             Brand_BMW  0.022085
# 3   Brand_Mercedes-Benz  0.011616
# 4      Brand_Mitsubishi -0.139396
# 5         Brand_Renault -0.182549
# 6          Brand_Toyota -0.057833
# 7      Brand_Volkswagen -0.090723
# 8            Body_hatch -0.144767
# 9            Body_other -0.099718
# 10           Body_sedan -0.184133
# 11           Body_vagon -0.123988
# 12             Body_van -0.151264
# 13      Engine Type_Gas -0.119555
# 14    Engine Type_Other -0.032004
# 15   Engine Type_Petrol -0.151227
# 16     Registration_yes  0.313740

# %%
data4["Body"].unique()
# Out:
# array(['sedan', 'van', 'crossover', 'vagon', 'other', 'hatch'],
#       dtype=object)

# %%
data4["Engine Type"].unique()
# Out:
# array(['Petrol', 'Diesel', 'Gas', 'Other'], dtype=object)

# %%
y_hat_test=reg.predict(x_test)

# %%
plt.scatter(y_test,y_hat_test,alpha=0.5)
plt.xlabel("targers(y_test)")
plt.ylabel("Predicted(y_hat_test)")
plt.xlim(6,13)
plt.ylim(6,13)
# Out:
# (6.0, 13.0)

# %%
pf_df=pd.DataFrame(np.exp(y_hat_test),columns=["predictions"])
pf_df.head()
# Out:
#     predictions
# 0   9019.553981
# 1   4676.562294
# 2   5911.099741
# 3   2388.441139
# 4  21884.289295

# %%
pf_df["Target"]=np.exp(y_test)
pf_df.head(768)
# Out:
#       predictions   Target
# 0     9019.553981      NaN
# 1     4676.562294   7900.0
# 2     5911.099741      NaN
# 3     2388.441139      NaN
# 4    21884.289295      NaN
# ..            ...      ...
# 763  31198.844003      NaN
# 764  16864.065252      NaN
# 765   5102.450159  22900.0
# 766   7644.854044      NaN
# 767  36174.196144      NaN
#
# [768 rows x 2 columns]

# %%
y_test=y_test.reset_index(drop=True)
y_test
# Out:
# 0       7.919356
# 1       8.846497
# 2       9.071078
# 3       7.408531
# 4      10.477288
#          ...
# 763    10.645425
# 764    10.085809
# 765     9.210340
# 766     9.210340
# 767    10.680516
# Name: Log_price, Length: 768, dtype: float64

# %%
pf_df["Target"]=np.exp(y_test)
pf_df
# Out:
#       predictions   Target
# 0     9019.553981   2750.0
# 1     4676.562294   6950.0
# 2     5911.099741   8700.0
# 3     2388.441139   1650.0
# 4    21884.289295  35500.0
# ..            ...      ...
# 763  31198.844003  42000.0
# 764  16864.065252  24000.0
# 765   5102.450159  10000.0
# 766   7644.854044  10000.0
# 767  36174.196144  43500.0
#
# [768 rows x 2 columns]

# %%
pf_df["residual"]=pf_df["Target"]-pf_df["predictions"]
pf_df["difference %"]=np.absolute(pf_df["residual"]/pf_df["Target"]*100)
pf_df
# Out:
#      predictions    Target  residual  difference %
# 0        9019.55   2750.00  -6269.55        227.98
# 1        4676.56   6950.00   2273.44         32.71
# 2        5911.10   8700.00   2788.90         32.06
# 3        2388.44   1650.00   -738.44         44.75
# 4       21884.29  35500.00  13615.71         38.35
# 5       11299.91  13000.00   1700.09         13.08
# 6        5222.23   3300.00  -1922.23         58.25
# 7       30506.75   6300.00 -24206.75        384.23
# 8       15753.03   8800.00  -6953.03         79.01
# 9        2867.81   3500.00    632.19         18.06
# 10       7251.59  12850.00   5598.41         43.57
# 11      33700.76  41000.00   7299.24         17.80
# 12       5892.44   6150.00    257.56          4.19
# 13      31461.24  42000.00  10538.76         25.09
# 14      18807.66  20200.00   1392.34          6.89
# 15      66766.35  99000.00  32233.65         32.56
# 16      14849.68  13500.00  -1349.68         10.00
# ...

# %%
pf_df.describe()
# Out:
#        predictions    Target  residual  difference %
# count       768.00    768.00    768.00        768.00
# mean      16409.62  18189.89   1780.27         39.05
# std       13332.11  18567.74   9774.53         90.18
# min        1247.03    800.00 -42600.56          0.05
# 25%        7625.42   7500.00  -1976.20         11.07
# 50%       12031.35  12349.50    431.81         23.73
# 75%       20390.15  21225.00   3644.46         40.68
# max       77368.26 126000.00  83364.28       1775.02

# %%
pd.options.display.max_rows=999
pd.set_option('display.float_format', lambda x:'%.2f' % x)

pf_df.sort_values("difference %")
# Out:
#      predictions    Target  residual  difference %
# 728     13893.01  13900.00      6.99          0.05
# 111      2998.07   3000.00      1.93          0.06
# 668     21320.87  21335.00     14.13          0.07
# 37      39534.94  39500.00    -34.94          0.09
# 478     12511.93  12500.00    -11.93          0.10
# 40      12924.64  12900.00    -24.64          0.19
# 509     44909.19  44999.00     89.81          0.20
# 228     12607.61  12650.00     42.39          0.34
# 289     26904.64  26800.00   -104.64          0.39
# 139     11344.56  11300.00    -44.56          0.39
# 156     11453.71  11500.00     46.29          0.40
# 546      7955.48   7990.00     34.52          0.43
# 246     32643.80  32500.00   -143.80          0.44
# 640     17594.77  17500.00    -94.77          0.54
# 271      8959.82   8900.00    -59.82          0.67
# 63      47350.60  47000.00   -350.60          0.75
# 505     39682.47  39999.00    316.53          0.79
# ...
