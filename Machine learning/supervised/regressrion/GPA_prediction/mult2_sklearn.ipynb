# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv('1.02.+Multiple+linear+regression.csv')
data
# Out:
#      SAT  Rand 1,2,3   GPA
# 0   1714           1  2.40
# 1   1664           3  2.52
# 2   1760           3  2.54
# 3   1685           3  2.74
# 4   1693           2  2.83
# ..   ...         ...   ...
# 79  1936           3  3.71
# 80  1810           1  3.71
# 81  1987           3  3.73
# 82  1962           1  3.76
# 83  2050           2  3.81
#
# [84 rows x 3 columns]

# %%
y=data['GPA']
x=data[['SAT','Rand 1,2,3']]

# %%
x
# Out:
#      SAT  Rand 1,2,3
# 0   1714           1
# 1   1664           3
# 2   1760           3
# 3   1685           3
# 4   1693           2
# ..   ...         ...
# 79  1936           3
# 80  1810           1
# 81  1987           3
# 82  1962           1
# 83  2050           2
#
# [84 rows x 2 columns]

# %%
reg=LinearRegression()
reg
# Out:
# LinearRegression()

# %%
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
r2=reg.score(x,y)
n=x.shape[0]
p=x.shape[1]

# %%
r2,n,p
# Out:
# (0.40668119528142843, 84, 2)

# %%
adj_Rsqueared=1-(1-r2)*(n-1)/(n-p-1)
adj_Rsqueared
# Out:
# 0.39203134825134023

# %% [markdown]
# ##FEATURE SELECTION

# %%
from sklearn.feature_selection import f_regression

# %%
f_regression(x,y)
# Out:
# (array([56.04804786,  0.17558437]), array([7.19951844e-11, 6.76291372e-01]))

# %%
p_values=f_regression(x,y)[1]
p_values
# Out:
# array([7.19951844e-11, 6.76291372e-01])

# %%
p_values.round(3)
# Out:
# array([0.   , 0.676])

# %%
reg_summary=pd.DataFrame(data=x.columns.values,columns=["Features"])
reg_summary
# Out:
#      Features
# 0         SAT
# 1  Rand 1,2,3

# %%
reg_summary["coeffficient"]=reg.coef_
reg_summary["p_value"]=p_values.round(3)
reg_summary
# Out:
#      Features  coeffficient  p_value
# 0         SAT      0.001654    0.000
# 1  Rand 1,2,3     -0.008270    0.676

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
scaler.fit(x)
# Out:
# StandardScaler()

# %%
scaled_data =scaler.transform(x)
scaled_data
# Out:
# array([[-1.26338288, -1.24637147],
#        [-1.74458431,  1.10632974],
#        [-0.82067757,  1.10632974],
#        [-1.54247971,  1.10632974],
#        [-1.46548748, -0.07002087],
#        [-1.68684014, -1.24637147],
#        [-0.78218146, -0.07002087],
#        [-0.78218146, -1.24637147],
#        [-0.51270866, -0.07002087],
#        [ 0.04548499,  1.10632974],
#        [-1.06127829,  1.10632974],
#        [-0.67631715, -0.07002087],
#        [-1.06127829, -1.24637147],
#        [-1.28263094,  1.10632974],
#        [-0.6955652 , -0.07002087],
#        [ 0.25721362, -0.07002087],
#        [-0.86879772,  1.10632974],
#        [-1.64834403, -0.07002087],
#        [-0.03150724,  1.10632974],
#        [-0.57045283,  1.10632974],
#        [-0.81105355,  1.10632974],
#        [-1.18639066,  1.10632974],
#        [-1.75420834,  1.10632974],
#        [-1.52323165, -1.24637147],
#        [ 1.23886453, -1.24637147],
#        [-0.18549169, -1.24637147],
#        [-0.5608288 , -1.24637147],
#        [-0.23361183,  1.10632974],
#        [ 1.68156984, -1.24637147],
#        [-0.4934606 , -0.07002087],
#        [-0.73406132, -1.24637147],
#        [ 0.85390339, -1.24637147],
#        [-0.67631715, -1.24637147],
#        [ 0.09360513,  1.10632974],
#        [ 0.33420585, -0.07002087],
#        [ 0.03586096, -0.07002087],
#        [-0.35872421,  1.10632974],
#        [ 1.04638396,  1.10632974],
#        [-0.65706909,  1.10632974],
#        [-0.13737155, -0.07002087],
#        [ 0.18984542,  1.10632974],
#        [ 0.04548499, -1.24637147],
#        [ 1.1618723 ,  1.10632974],
#        [-1.37887123, -1.24637147],
#        [ 1.39284898, -1.24637147],
#        [ 0.76728713, -0.07002087],
#        [-0.20473975, -0.07002087],
#        [ 1.06563201, -1.24637147],
#        [ 0.11285319, -1.24637147],
#        [ 1.28698467,  1.10632974],
#        [-0.41646838,  1.10632974],
#        [ 0.09360513, -1.24637147],
#        [ 0.59405462, -0.07002087],
#        [-2.03330517, -0.07002087],
#        [ 0.32458182, -1.24637147],
#        [ 0.40157405, -1.24637147],
#        [-1.10939843, -0.07002087],
#        [ 1.03675993, -1.24637147],
#        [-0.61857297, -0.07002087],
#        [ 0.44007016, -0.07002087],
#        [ 1.14262424, -1.24637147],
#        [-0.35872421,  1.10632974],
#        [ 0.45931822,  1.10632974],
#        [ 1.88367444,  1.10632974],
#        [ 0.45931822, -1.24637147],
#        [-0.12774752, -0.07002087],
#        [ 0.04548499,  1.10632974],
#        [ 0.85390339, -0.07002087],
#        [ 0.15134931, -0.07002087],
#        [ 0.8250313 ,  1.10632974],
#        [ 0.84427936,  1.10632974],
#        [-0.64744506, -1.24637147],
#        [ 1.24848856, -1.24637147],
#        [ 0.85390339,  1.10632974],
#        [ 1.69119387,  1.10632974],
#        [ 1.6334497 ,  1.10632974],
#        [ 1.46021718, -1.24637147],
#        [ 1.68156984, -0.07002087],
#        [-0.02188321,  1.10632974],
#        [ 0.87315144,  1.10632974],
#        [-0.33947615, -1.24637147],
#        [ 1.3639769 ,  1.10632974],
#        [ 1.12337618, -1.24637147],
#        [ 1.97029069, -0.07002087]])

# %%
reg1=LinearRegression()
reg1.fit(scaled_data,y)
# Out:
# LinearRegression()

# %%
new_data=pd.DataFrame(data=[[1800,2],[1600,1]],columns=["SAT","Rand 1,2,3"])
new_data
# Out:
#     SAT  Rand 1,2,3
# 0  1800           2
# 1  1600           1

# %%
scaled=scaler.transform(new_data)
scaled
# Out:
# array([[-0.43571643, -0.07002087],
#        [-2.36052213, -1.24637147]])

# %%
reg1.predict(scaled)
# Out:
# array([3.25586821, 2.93342967])
